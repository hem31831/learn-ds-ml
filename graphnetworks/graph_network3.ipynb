# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("datasets\dataset.csv")

# %%
#sort by user and date because we want to visualize in which order (date) the users (user_id) read the chapters
df = df.sort_values(by=["user_id", "date_created"])

# %%
# a chapter belongs to a specific book and chapter alone wouldn't be unique.
# the network is build from nodes (source, target) so we have to combine chapter and book in a single column
df["source"] = df["chapter"] + " " + df["book"]

# %%
#This is a very elegant way to do this. My first idea was about using a row based algorithm. So I learned a useful pattern
df["target"] = df["source"].shift(-1)

# %%
# And again: creation of additional columns using shifting and filter afterwards is a usefull pattern to deal with hierarchical
# structures in a flat table
df["user_check"] = df["user_id"].shift(-1)

# %%
# I am wondering whether pandas offers a similar way beside apply and a userdefined function to achieve this
df["keep_drop"] = np.where((df["user_check"] == df["user_id"]), df["user_id"], np.nan)

# %%
df = df.dropna(subset=["keep_drop"])

# %%
# create the networkx network
G = nx.from_pandas_edgelist(df, "source", "target", create_using=nx.DiGraph)

# %% [markdown]
# ### 3.1 Analyzing the network

# %%
#calculate centrality measures and add them to the graph
out = nx.out_degree_centrality(G)
nx.set_node_attributes(G,out,"out-degree")

bb = nx.betweenness_centrality(G)
nx.set_node_attributes(G,bb,"betweenness")

eigen = nx.eigenvector_centrality(G)
nx.set_node_attributes(G,eigen,"eigen")

# %%
# create a list from the node data containing also the attributes
data_list = list(G.nodes(data=True))
data_list
# Out:
# [('chapter-8 fain3',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('chapter-1 ramamurthy',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 5.091126065445408e-07,
#    'eigen': 3.4050436005164946e-44}),
#  ('chapter-1 thomas',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 1.1071550858649084e-42}),
#  ('chapter-4 mcnamara',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0010951012166773072,
#    'eigen': 7.421038983061692e-11}),
#  ('chapter-1 mcnamara',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0015405747474037806,
#    'eigen': 5.1056640257968935e-11}),
#  ('chapter-2 mcnamara',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.002719170431554393,
#    'eigen': 8.256859417671816e-11}),
#  ('chapter-9 hillard',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 3.365361593998789e-11}),
#  ('chapter-2 vos',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.011976874068960324,
#    'eigen': 3.5301797859518134e-11}),
#  ('chapter-3 mcnamara',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 9.724050785000728e-05,
#    'eigen': 5.680736551263589e-11}),
#  ('chapter-5 mcnamara',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 5.600238671989948e-06,
#    'eigen': 5.1056640257968935e-11}),
#  ('chapter-6 mcnamara',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 3.5129599687473976e-11}),
#  ('chapter-4 wong',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('chapter-2 wong',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 3.806785930821228e-26}),
#  ('chapter-6 infante',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  ('chapter-7 infante',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 6.376366434125559e-25}),
#  ('chapter-8 wittig4',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  ('chapter-9 wittig4',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 6.376366434125559e-25}),
#  ('chapter-2 lane',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  ('chapter-11 lane',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 5.091126065445408e-07,
#    'eigen': 6.376366434125559e-25}),
#  ('chapter-12 lane',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.0535280063547752e-23}),
#  ('welcome robinson4',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('chapter-6 robinson4',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 1.0182252130890815e-06,
#    'eigen': 3.806785930821228e-26}),
#  ('chapter-4 robinson4',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 1.0182252130890815e-06,
#    'eigen': 1.2372054275168986e-24}),
#  ('chapter-8 robinson4',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.9833354699578602e-23}),
#  ('chapter-8 borgatti',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('welcome borgatti',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0011775774589375227,
#    'eigen': 1.4960051529769776e-13}),
#  ('chapter-8 lauret',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  ('chapter-11 lauret',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 5.091126065445408e-07,
#    'eigen': 6.376366434125559e-25}),
#  ('about-this-book fain2',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 6.1860271375844965e-25}),
#  ('chapter-2 infante',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('chapter-3 infante',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 3.4050436005164946e-44}),
#  ('chapter-3 rfeldman',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('chapter-2 rfeldman',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 3.4050436005164946e-44}),
#  ('chapter-1 kopec2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 9.164026917801734e-06,
#    'eigen': 3.4050436005164946e-44}),
#  ('welcome morales',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 1.6291603409425305e-05,
#    'eigen': 1.1071550858649084e-42}),
#  ('welcome zai',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 2.2910067294504336e-05,
#    'eigen': 2.3642352732919515e-41}),
#  ('welcome hillard',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 3.5637882458117855e-05,
#    'eigen': 3.729714507825742e-40}),
#  ('chapter-2 kopec2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 3.6656107671206934e-05,
#    'eigen': 4.6354168959701515e-39}),
#  ('about-this-book godsey',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 3.920167070392964e-05,
#    'eigen': 4.727093773954761e-38}),
#  ('chapter-2 godsey',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 4.072900852356326e-05,
#    'eigen': 4.06773336146035e-37}),
#  ('chapter-5 godsey',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 4.12381211301078e-05,
#    'eigen': 1.9033929654060212e-25}),
#  ('part-2 godsey',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 4.072900852356326e-05,
#    'eigen': 1.9033929653758744e-25}),
#  ('chapter-6 godsey',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 3.920167070392964e-05,
#    'eigen': 1.9033929651804225e-25}),
#  ('chapter-8 godsey',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 3.920167070392964e-05,
#    'eigen': 2.349385603384239e-18}),
#  ('chapter-5 umali',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.4520000828679977e-18}),
#  ('chapter-9 godsey',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 2.8510305966494284e-05,
#    'eigen': 3.8013806041930195e-18}),
#  ('chapter-11 godsey',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 2.2910067294504336e-05,
#    'eigen': 6.1506933837624e-18}),
#  ('foreword perrin',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 1.6291603409425305e-05,
#    'eigen': 3.80131286243738e-18}),
#  ('about-this-book wittig',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 8.654914311257194e-06,
#    'eigen': 2.3493176712893036e-18}),
#  ('welcome iannone',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 1.4519370424929845e-18}),
#  ('about-the-cover shukla',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('chapter-4 harrison',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 1.0182252130890815e-06,
#    'eigen': 3.4050436005164946e-44}),
#  ('chapter-6 shukla',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 1.0182252130890815e-06,
#    'eigen': 1.1071550858649084e-42}),
#  ('chapter-1 shukla',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 7.613571861642456e-26}),
#  ('chapter-8 apeltsin',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  ('chapter-1 grummitt',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('about-this-book veen',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 3.4050436005164946e-44}),
#  ('about-this-book hahn',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('chapter-1 nickoloff',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 6.61846388507903e-06,
#    'eigen': 1.2301543721308735e-18}),
#  ('welcome nickoloff2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 7.602772133861663e-19}),
#  ('chapter-3 cantelon2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 7.63668909816811e-06,
#    'eigen': 7.602772133861663e-19}),
#  ('chapter-4 cantelon2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 8.145801704712652e-06,
#    'eigen': 1.2301543530969443e-18}),
#  ('chapter-3 derosa',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 7.63668909816811e-06,
#    'eigen': 7.6027719435223685e-19}),
#  ('chapter-14 maras',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 6.10935127853449e-06,
#    'eigen': 4.698771397107778e-19}),
#  ('chapter-1 nickoloff2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 3.5637882458117855e-06,
#    'eigen': 7.602766518852418e-19}),
#  ('chapter-7 hocking2',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 4.698766162777124e-19}),
#  ('chapter-1 hillard',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('chapter-8 orland',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 4.6354168959701515e-39}),
#  ('chapter-1 lyon',
#   {'out-degree': 0.0042796005706134095,
#    'betweenness': 0.0062605577226782175,
#    'eigen': 4.458135764403248e-14}),
#  ('about-the-cover-illustration juric2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 9.774962045655183e-05,
#    'eigen': 1.9251489022001403e-14}),
#  ('chapter-2 juric2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 6.61846388507903e-05,
#    'eigen': 1.470264385126776e-14}),
#  ('chapter-6 juric2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 3.360143203193969e-05,
#    'eigen': 1.1295571152118305e-14}),
#  ('chapter-5 juric2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 8.745058809970494e-15}),
#  ('chapter-5 buonanno',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  ('chapter-6 buonanno',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 1.5273378196336224e-06,
#    'eigen': 6.376366434125559e-25}),
#  ('chapter-7 buonanno',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 2.036450426178163e-06,
#    'eigen': 1.0535280063547752e-23}),
#  ('chapter-8 buonanno',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 1.5273378196336224e-06,
#    'eigen': 1.1446053597496731e-22}),
#  ('chapter-9 buonanno',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 9.198812692884685e-22}),
#  ('chapter-4 payette3',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 5.091126065445408e-07,
#    'eigen': 8.901480659557575e-19}),
#  ('chapter-3 payette3',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.501417597806412e-19}),
#  ('chapter-5 payette3',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.440289806702469e-18}),
#  ('chapter-7 falk',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('welcome zumel3',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 5.091126065445408e-07,
#    'eigen': 3.4050436005164946e-44}),
#  ('b-important-statistical-concepts zumel3',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.710178896231837e-26}),
#  ('chapter-1 chollet',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('welcome apeltsin',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.001557884576026295,
#    'eigen': 1.1406896061730246e-42}),
#  ('chapter-1 falk',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 1.0182252130890815e-05,
#    'eigen': 2.471545738277926e-41}),
#  ('chapter-2 falk',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 1.0182252130890815e-05,
#    'eigen': 1.142035779246368e-25}),
#  ('chapter-3 falk',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 1.0182252130890815e-05,
#    'eigen': 1.779672422658924e-24}),
#  ('chapter-4 falk',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.7225706336966057e-24}),
#  ('chapter-6 falk',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 4.072900852356326e-06,
#    'eigen': 1.7225706336966057e-24}),
#  ('chapter-1 heitz',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 1.6654688447342877e-24}),
#  ('chapter-2 sbarski',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  ('chapter-5 negro',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  ('chapter-7 raychaudhuri',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('chapter-1 roestenburg',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 1.5273378196336224e-06,
#    'eigen': 3.806785930821228e-26}),
#  ('about-this-book suereth',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 2.036450426178163e-06,
#    'eigen': 3.806785930821228e-26}),
#  ('chapter-2 suereth',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 1.5273378196336224e-06,
#    'eigen': 2.1203024000187725e-18}),
#  ('about-this-book psaltis',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.3104189350989486e-18}),
#  ('about-this-book urma2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('about-this-book urma',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 3.4050436005164946e-44}),
#  ('chapter-2 seemann2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('chapter-0 wexler',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 3.4050436005164946e-44}),
#  ('chapter-3 seemann2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('about-this-book seemann',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 5.091126065445408e-07,
#    'eigen': 3.4050436005164946e-44}),
#  ('chapter-5 seemann2',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 1.1071550858649084e-42}),
#  ('chapter-3 kuate',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  ('chapter-6 kuate',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 6.376366434125559e-25}),
#  ('chapter-1 gustedt',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('chapter-7 birchall',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.710178896231837e-26}),
#  ('chapter-3 palmer',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  ('chapter-6 negro',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.501417597806415e-19}),
#  ('chapter-7 negro',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 8.901480659557578e-19}),
#  ('chapter-14 lock',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  ('welcome larocca',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  ('welcome krunic',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0005198039712819762,
#    'eigen': 3.4050436005164946e-44}),
#  ('chapter-1 jain',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0020629242817184795,
#    'eigen': 2.471545738277926e-41}),
#  ('welcome vermeulen',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 3.156498160576153e-05,
#    'eigen': 1.9251489022001403e-14}),
#  ('welcome lyon',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0005147128452165307,
#    'eigen': 8.325282404162424e-15}),
#  ('chapter-2 ryan',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 9.164026917801734e-05,
#    'eigen': 1.9251489022001403e-14}),
#  ('welcome davisr',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 6.007528757225581e-05,
#    'eigen': 8.325282404162424e-15}),
#  ('chapter-3 wolohan',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 2.74920807534052e-05,
#    'eigen': 3.605861655960107e-15}),
#  ('chapter-1 langr',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  ('chapter-2 skeet5',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0027201886567674812,
#    'eigen': 3.973107825939102e-13}),
#  ('about-this-book luksa',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0006873020188351301,
#    'eigen': 1.6999918703701515e-13}),
#  ('welcome wong',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0011704498824458992,
#    'eigen': 7.281429598218313e-14}),
#  ('about-this-book nicieja2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0016535977460566684,
#    'eigen': 3.121955640763972e-14}),
#  ('welcome ponelat',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.9251489022001403e-14}),
#  ('welcome mcnamara',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.006393436112986343,
#    'eigen': 1.9251489022001403e-14}),
#  ('chapter-1 vos',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0068765839765971126,
#    'eigen': 8.325282404162424e-15}),
#  ('chapter-17 luksa',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 6.262085060497851e-05,
#    'eigen': 1.4388537660129065e-11}),
#  ('chapter-2 lyon',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0005457687142157477,
#    'eigen': 5.864577248715616e-12}),
#  ('chapter-3 lyon',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.001028916577826517,
#    'eigen': 4.03490150754274e-12}),
#  ('chapter-1 wong',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.01218510112503704,
#    'eigen': 2.428801641638738e-11}),
#  ('chapter-1 orland',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.01266824898864781,
#    'eigen': 9.899478756258318e-12}),
#  ('chapter-2 orland',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.013151396852258579,
#    'eigen': 4.034901507542702e-12}),
#  ('chapter-15 skeet5',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.017898871908286422,
#    'eigen': 6.3671859662288245e-12}),
#  ('chapter-1 thymegobbel2',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0027680452417826683,
#    'eigen': 4.917906714666471e-12}),
#  ('chapter-8 thymegobbel2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0002744116949275075,
#    'eigen': 2.072831421152678e-12}),
#  ('chapter-2 ponelat',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0007575595585382767,
#    'eigen': 1.5158083965000882e-12}),
#  ('chapter-2 nickoloff2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.001240707422149046,
#    'eigen': 1.1125884238500316e-12}),
#  ('chapter-7 luksa',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.005832394020574259,
#    'eigen': 8.28185813936186e-13}),
#  ('b-big-o-notation larocca',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.00017869852489713382,
#    'eigen': 3.5178004333666295e-13}),
#  ('chapter-11 luksa',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.001660725322548292,
#    'eigen': 6.369509257146386e-14}),
#  ('chapter-2 ceder4',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.002143873186159061,
#    'eigen': 4.739110847080703e-14}),
#  ('chapter-3 nickoloff2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0026270210497698304,
#    'eigen': 3.537871782414483e-14}),
#  ('chapter-1 mccreary',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0031101689133805994,
#    'eigen': 1.513832534964454e-14}),
#  ('chapter-9 ceder4',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.003593316776991369,
#    'eigen': 1.1357851871672767e-14}),
#  ('chapter-3 luksa',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.007512465622171244,
#    'eigen': 6.807473553581553e-12}),
#  ('chapter-1 ceder4',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 3.156498160576153e-05,
#    'eigen': 2.8912888723166217e-12}),
#  ('chapter-2 rosenbaum2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0005147128452165307,
#    'eigen': 1.229464213578339e-12}),
#  ('chapter-3 skeet5',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.005801847264181587,
#    'eigen': 7.961620623826596e-12}),
#  ('welcome robey',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.006126661107157005,
#    'eigen': 3.389946482021214e-12}),
#  ('about-this-book cukic',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0066098089707677735,
#    'eigen': 1.4450608886852808e-12}),
#  ('chapter-4 skeet3',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.030718836453684506,
#    'eigen': 7.182310596373688e-12}),
#  ('chapter-5 skeet3',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.004559612504212907,
#    'eigen': 1.113852958751909e-11}),
#  ('chapter-7 skeet3',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0018083679784462088,
#    'eigen': 9.303446246135857e-12}),
#  ('chapter-8 skeet3',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0007875972023244045,
#    'eigen': 3.951545835426843e-12}),
#  ('chapter-1 ponge',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0012707450659351738,
#    'eigen': 2.928060509983602e-12}),
#  ('chapter-4 ponge',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.001753892929545943,
#    'eigen': 1.2476752404948432e-12}),
#  ('chapter-5 skeet5',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0022370407931567122,
#    'eigen': 5.322538607372487e-13}),
#  ('chapter-3 skeet3',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.023648789686600467,
#    'eigen': 8.35701997528278e-12}),
#  ('chapter-15 skeet3',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 3.156498160576153e-05,
#    'eigen': 3.5246308068478746e-12}),
#  ('chapter-2 skeet3',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0005147128452165307,
#    'eigen': 1.4883793079939992e-12}),
#  ('about-this-book skeet5',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0014718445455202676,
#    'eigen': 3.951545835426843e-12}),
#  ('chapter-10 skeet5',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.00012625992642304612,
#    'eigen': 3.389946482021214e-12}),
#  ('about-this-book chang',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0006094077900338153,
#    'eigen': 1.4450608886852808e-12}),
#  ('chapter-9 skeet3',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0010925556536445845,
#    'eigen': 1.0773411226976094e-12}),
#  ('chapter-10 skeet3',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0015757035172553537,
#    'eigen': 4.606442351463739e-13}),
#  ('chapter-1 gallant',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.002058851380866123,
#    'eigen': 1.9716941835179127e-13}),
#  ('  madden',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.033045223348881124,
#    'eigen': 0.06883741526272602}),
#  (' a-setting-up-java-and-maven madden',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0180067622364036,
#    'eigen': 0.025082697373882915}),
#  (' chapter-3 madden',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.018692075006089562,
#    'eigen': 0.04047020466040671}),
#  (' chapter-2 kopec2',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0064445218067382196,
#    'eigen': 0.016686750753255132}),
#  (' chapter-1 winkler',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.007769310434878319,
#    'eigen': 0.01393264332490994}),
#  (' chapter-1 stoneman',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.006485788702220748,
#    'eigen': 0.012567070260605325}),
#  (' b-big-o-notation larocca',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0034168244067225946,
#    'eigen': 0.004580039716196145}),
#  (' chapter-3 mcilwraith',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0034112241680506047,
#    'eigen': 0.001223348307644117}),
#  (' c-core-data-structures larocca',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0034056239293786144,
#    'eigen': 0.00032676372149452156}),
#  (' chapter-2 foulds2',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0038816442164977608,
#    'eigen': 0.00013193659035282417}),
#  (' chapter-2 ponelat',
#   {'out-degree': 0.004992867332382311,
#    'betweenness': 0.014979635288121238,
#    'eigen': 0.08081405688104101}),
#  (' welcome windmill',
#   {'out-degree': 0.004992867332382311,
#    'betweenness': 0.01348498475356089,
#    'eigen': 0.02170376970341983}),
#  (' chapter-7 windmill',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0013774618934798066,
#    'eigen': 0.007908508758691283}),
#  (' chapter-8 windmill',
#   {'out-degree': 0.0042796005706134095,
#    'betweenness': 0.00777498355039608,
#    'eigen': 0.013100453316028752}),
#  (' chapter-7 metzgar',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.003424307336885936,
#    'eigen': 0.012909662163378787}),
#  (' chapter-2 davis4',
#   {'out-degree': 0.0042796005706134095,
#    'betweenness': 0.023314296295727475,
#    'eigen': 0.1217226549227036}),
#  (' chapter-1 posta2',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.0028087209272662163,
#    'eigen': 0.0008955848865236301}),
#  (' chapter-1 ketelsen',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 0.026135166799765717}),
#  (' welcome love',
#   {'out-degree': 0.004992867332382311,
#    'betweenness': 0.014727856132800447,
#    'eigen': 0.045210034009106254}),
#  (' chapter-1 yuen',
#   {'out-degree': 0.004992867332382311,
#    'betweenness': 0.029097145207565962,
#    'eigen': 0.16497965482846708}),
#  (' chapter-5 bhargava',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0012657165445015175,
#    'eigen': 0.013964631851032588}),
#  (' chapter-3 gold',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' introduction wittig3',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0022456039863872662,
#    'eigen': 0.002496230476111642}),
#  (' chapter-2 rosenberg',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0007275839375974699,
#    'eigen': 0.0006667852282209629}),
#  (' chapter-6 pharrington',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.00072198369892548,
#    'eigen': 0.00024303047100326683}),
#  (' about-this-book urma2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.007653629197110963,
#    'eigen': 0.02241034362793881}),
#  (' chapter-6 kaiser',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0027214610186855415,
#    'eigen': 0.008166511762449999}),
#  (' a-installing-strange vos',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.002715860780013551,
#    'eigen': 0.0029759443446781574}),
#  (' chapter-3 vos',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0027102605413415605,
#    'eigen': 0.0007948200075452897}),
#  (' chapter-1 urma2',
#   {'out-degree': 0.004992867332382311,
#    'betweenness': 0.020689627908230476,
#    'eigen': 0.10740146389401811}),
#  (' chapter-1 bechberger',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.00481115353836188,
#    'eigen': 0.04292450139092717}),
#  (' chapter-8 lauret',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-8 stevens2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 0.0002598979918854947}),
#  (' chapter-2 picheta',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 5.314474144765475e-15}),
#  (' chapter-9 langr',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 5.314474144765475e-15}),
#  (' chapter-2 skeet5',
#   {'out-degree': 0.007132667617689016,
#    'betweenness': 0.03365468026300982,
#    'eigen': 0.07227484020086057}),
#  (' about-this-book mcfedries',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.008986461272170825,
#    'eigen': 0.020345429428481263}),
#  (' chapter-3 skeet5',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0017327734622992965,
#    'eigen': 0.04658207133555285}),
#  (' chapter-1 maras',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' welcome ramamurthy',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.006867676967060848,
#    'eigen': 0.013579907344324243}),
#  (' chapter-6 ramamurthy',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0042551771959058,
#    'eigen': 0.011706385722806616}),
#  (' about-this-book walls7',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-2 walls5',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 6.376366434125559e-25}),
#  (' chapter-7 cukic',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-1 gustedt',
#   {'out-degree': 0.006419400855920115,
#    'betweenness': 0.025273954625435305,
#    'eigen': 0.06931667756790293}),
#  (' chapter-5 curcic',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0009754597541393401,
#    'eigen': 0.01851424226737668}),
#  (' chapter-7 curcic',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0004882389896762146,
#    'eigen': 0.006747306333124191}),
#  (' chapter-8 curcic',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 0.0018021986488434866}),
#  (' chapter-3 trask2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  (' chapter-4 horsdal2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.00048263875100422465,
#    'eigen': 3.4050436005164946e-44}),
#  (' chapter-2 butcher',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0009642592767953603,
#    'eigen': 1.1071550858649084e-42}),
#  (' about-this-book shukla',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0041448173184496645,
#    'eigen': 0.009614748256966187}),
#  (' about-this-book butcher',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0012240303614565874,
#    'eigen': 0.005796402652679598}),
#  (' chapter-5 butcher',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 0.002112106106011684}),
#  (' chapter-3 stoneman',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-1 dean',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.003930205680038437,
#    'eigen': 0.0013255932964799538}),
#  (' chapter-2 robinson4',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0019509195082786802,
#    'eigen': 0.0003540329451612258}),
#  (' chapter-6 stojanovic',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0014662443068482775,
#    'eigen': 0.00013556716479793245}),
#  (' chapter-1 hanchett',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0004887481022827591,
#    'eigen': 4.939977077684005e-05}),
#  (' chapter-1 stojanovic',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 1.0182252130890815e-06,
#    'eigen': 1.80008716514929e-05}),
#  (' chapter-7 hanchett',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 4.939977077684005e-05}),
#  (' chapter-1 dabit',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' about-this-book saumont2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0029390218694577445,
#    'eigen': 0.0046745373287501776}),
#  (' chapter-1 saumont2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.000656166881076539,
#    'eigen': 0.001703267694863834}),
#  (' about-this-book kuhn',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0015112315501099335,
#    'eigen': 0.003626898945462698}),
#  (' chapter-1 jemerov',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.0012174991603278512,
#    'eigen': 0.002213415712534852}),
#  (' chapter-7 saumont2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 0.0005911416671303181}),
#  (' chapter-2 jemerov',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0014204138687898497,
#    'eigen': 0.005094253104112991}),
#  (' chapter-3 jemerov',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0009337022169332688,
#    'eigen': 0.0018562306099223}),
#  (' chapter-2 preukschat',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.004256499916684055,
#    'eigen': 0.008507761399137457}),
#  (' chapter-3 preukschat',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0012433679464167369,
#    'eigen': 0.01231809863196198}),
#  (' chapter-3 atencio',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-4 atencio',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 6.376366434125559e-25}),
#  (' chapter-1 davis4',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.008588059262273346,
#    'eigen': 0.09267830070452822}),
#  (' chapter-2 harenslak',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.004774069875966217,
#    'eigen': 0.01281203186890355}),
#  (' chapter-2 hillard',
#   {'out-degree': 0.005706134094151213,
#    'betweenness': 0.01985155143244039,
#    'eigen': 0.06471023063269533}),
#  (' chapter-2 windmill',
#   {'out-degree': 0.0042796005706134095,
#    'betweenness': 0.004312493710489465,
#    'eigen': 0.004156698460927379}),
#  (' chapter-1 kochmar',
#   {'out-degree': 0.0042796005706134095,
#    'betweenness': 0.007216551746340606,
#    'eigen': 0.05010072181123976}),
#  (' chapter-3 windmill',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.0030801360250418955,
#    'eigen': 0.039863590193040165}),
#  (' chapter-4 windmill',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 0.014527654000064569}),
#  (' chapter-5 windmill',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0025817147832347905,
#    'eigen': 0.019822073108683613}),
#  (' chapter-6 windmill',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0025761145445628002,
#    'eigen': 0.007223922497779592}),
#  (' chapter-1 hazzard',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 0.004773826346180464}),
#  (' chapter-3 richer',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-2 richer',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 5.091126065445408e-07,
#    'eigen': 7.97171121714821e-15}),
#  (' chapter-6 richer',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 7.971711217129177e-15}),
#  (' welcome krunic',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0049907953248852,
#    'eigen': 0.0005506643147418131}),
#  (' welcome khorikov',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.008267489028263627,
#    'eigen': 0.00769525286729711}),
#  (' chapter-1 krunic',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0013139161987396541,
#    'eigen': 0.002055244718596052}),
#  (' chapter-3 hurbans',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0052669109873257035,
#    'eigen': 0.017281698675841877}),
#  (' chapter-1 hillard',
#   {'out-degree': 0.003566333808844508,
#    'betweenness': 0.005946206644974923,
#    'eigen': 0.04345948048561934}),
#  (' chapter-14 foulds',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' welcome foulds2',
#   {'out-degree': 0.003566333808844508,
#    'betweenness': 0.007485774162713513,
#    'eigen': 0.0032831017516872065}),
#  (' chapter-14 rhys',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-4 tudose',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-1 siriwardena',
#   {'out-degree': 0.008559201141226819,
#    'betweenness': 0.04066750842519482,
#    'eigen': 0.15838598023228218}),
#  (' welcome tudose',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.005086370928117864,
#    'eigen': 0.048212522198348935}),
#  (' chapter-1 nickoloff2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0011226468480303399,
#    'eigen': 0.006976038208798066}),
#  (' welcome scott4',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0036551164963850064,
#    'eigen': 0.029843685767351132}),
#  (' welcome yuen',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.00832648481398371,
#    'eigen': 0.019328073620296635}),
#  (' welcome rioux',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0006855746724914969,
#    'eigen': 0.005162574667707942}),
#  (' welcome kochmar',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0006799744338195061,
#    'eigen': 0.00137894302796672}),
#  (' chapter-2 kochmar',
#   {'out-degree': 0.003566333808844508,
#    'betweenness': 0.010666984663294618,
#    'eigen': 0.035334513301314936}),
#  (' chapter-1 fain2',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.004526041072753175,
#    'eigen': 0.005851569439532919}),
#  (' welcome riscutia',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.01633389853786467,
#    'eigen': 0.0160584144166678}),
#  (' welcome osherove4',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.00813000244551838,
#    'eigen': 0.001974837710255908}),
#  (' about-this-book osherove2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0022380712898541497,
#    'eigen': 0.0005274207552188429}),
#  (' about-this-book lauret',
#   {'out-degree': 0.005706134094151213,
#    'betweenness': 0.02976833206914405,
#    'eigen': 0.11439508624887694}),
#  (' about-the-author lauret',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.000486711651856581,
#    'eigen': 0.03055137363034954}),
#  (' part-1 lauret',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.00048111141318459103,
#    'eigen': 0.011132373718263033}),
#  (' chapter-1 lauret',
#   {'out-degree': 0.007132667617689016,
#    'betweenness': 0.0320760256697409,
#    'eigen': 0.21764659533219696}),
#  (' about-this-book palmer',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 0.05812638008228512}),
#  (' chapter-2 atencio3',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.006140067858335498,
#    'eigen': 0.04417957254764113}),
#  (' chapter-1 atencio3',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0028873416401899,
#    'eigen': 0.025644700673630158}),
#  (' chapter-5 atencio3',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0006570983073654388,
#    'eigen': 0.00684912997401291}),
#  (' chapter-6 atencio3',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 0.016098254553702892}),
#  (' welcome mcnamara',
#   {'out-degree': 0.003566333808844508,
#    'betweenness': 0.013982614735564948,
#    'eigen': 0.0342947328168145}),
#  (' chapter-1 mcnamara',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.003912383395184204,
#    'eigen': 0.012496288377362998}),
#  (' chapter-6 mcnamara',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.00088340674009816,
#    'eigen': 0.004553349259482013}),
#  (' chapter-1 williams4',
#   {'out-degree': 0.006419400855920115,
#    'betweenness': 0.02560079768159569,
#    'eigen': 0.12034770285148629}),
#  (' chapter-2 mcnamara',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 0.04385590410487133}),
#  (' chapter-8 mcnamara',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 0.009158970105619854}),
#  (' about-this-book youngman',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0022249849625547227,
#    'eigen': 0.0021970526779942164}),
#  (' chapter-1 youngman',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.00048772987706967004,
#    'eigen': 0.0005867930048830916}),
#  (' chapter-2 youngman',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 0.00021383286185324975}),
#  (' chapter-1 osherove2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0021307692851785577,
#    'eigen': 0.019215356916446776}),
#  (' about-this-book kabacoff2',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.005664140862786413,
#    'eigen': 0.0034810361405072598}),
#  (' chapter-1 kabacoff2',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0014636987438155548,
#    'eigen': 0.0015255323987093522}),
#  (' chapter-19 kabacoff2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 0.0004074980093949949}),
#  (' chapter-2 kabacoff2',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0004892572148893037,
#    'eigen': 0.0007045508758686308}),
#  (' chapter-4 kabacoff2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 0.0002567995809258906}),
#  (' chapter-6 rfeldman',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 5.091126065445408e-07,
#    'eigen': 2.6429460887540512e-17}),
#  (' appendix-a rfeldman',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 5.091126065445408e-07,
#    'eigen': 1.5060571683077753e-17}),
#  (' chapter-7 rfeldman',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 5.091126065445408e-07,
#    'eigen': 1.9951009754944827e-17}),
#  (' chapter-6 khorikov',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.006079675496978428,
#    'eigen': 0.04816883348110947}),
#  (' chapter-1 khorikov',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.007743997220145257,
#    'eigen': 0.027938221163437135}),
#  (' chapter-5 seemann',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 5.314474144765475e-15}),
#  (' chapter-4 seemann',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 5.314474144765475e-15}),
#  (' chapter-12 rhys',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0006917749551017414,
#    'eigen': 0.004271124317757275}),
#  (' chapter-1 allaire',
#   {'out-degree': 0.003566333808844508,
#    'betweenness': 0.013262814626879504,
#    'eigen': 0.07310219706088995}),
#  (' about-this-book allaire',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0020898826207165168,
#    'eigen': 0.03214012046707141}),
#  (' appendix-a allaire',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0020842823820445273,
#    'eigen': 0.011716217568049032}),
#  (' chapter-10 rhys',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 6.864534978242226e-05,
#    'eigen': 0.0015570889383424837}),
#  (' chapter-1 rhys',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0025711061598918295,
#    'eigen': 0.019727815138041067}),
#  (' chapter-2 rhys',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0025655059212198387,
#    'eigen': 0.005270765288065143}),
#  (' chapter-2 allaire',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.007270094837194672,
#    'eigen': 0.07668540337969364}),
#  (' chapter-15 rhys',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 0.02049312539223409}),
#  (' chapter-3 zai',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0035895244051533486,
#    'eigen': 0.003412781309033652}),
#  (' chapter-2 zai',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.001416004589965313,
#    'eigen': 0.0012442717718615813}),
#  (' welcome morales',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.014858397427839464,
#    'eigen': 0.00559916612239263}),
#  (' chapter-1 morales',
#   {'out-degree': 0.0042796005706134095,
#    'betweenness': 0.012337027113237933,
#    'eigen': 0.020571342181586984}),
#  (' chapter-8 morales',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0030537077036876937,
#    'eigen': 0.008740699889079785}),
#  (' chapter-9 morales',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 0.003185454332125305}),
#  (' chapter-7 lock',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0004841660888238583,
#    'eigen': 1.903392965410614e-26}),
#  (' welcome ponelat',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.002388501793603713,
#    'eigen': 5.710178896231844e-26}),
#  (' chapter-1 ponelat',
#   {'out-degree': 0.0042796005706134095,
#    'betweenness': 0.019431818345096056,
#    'eigen': 0.09936848811177658}),
#  (' chapter-14 lock',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0025130825300054317,
#    'eigen': 0.03620804092316164}),
#  (' chapter-3 smith3',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.002507482291333442,
#    'eigen': 0.00966993971794278}),
#  (' chapter-1 smith3',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0025018820526614524,
#    'eigen': 0.003523497920979534}),
#  (' chapter-2 smith3',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.008590605785420771,
#    'eigen': 0.0037004789555780543}),
#  (' chapter-2 grant2',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.011232496890412929,
#    'eigen': 0.0013510230378284583}),
#  (' chapter-8 lock',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 0.0004923127551635804}),
#  (' chapter-6 juric2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-7 juric2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 6.376366434125559e-25}),
#  (' part-1 windmill',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0009476363461340563,
#    'eigen': 0.0034988418886300458}),
#  (' chapter-2 orland',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.002410648191988401,
#    'eigen': 3.9105208474361047e-23}),
#  (' chapter-8 jones9',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-1 jones9',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 1.0182252130890815e-06,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-2 jones9',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 1.0182252130890815e-06,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-1 jones5',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 6.376366434125559e-25}),
#  (' chapter-3 bhargava',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.005127764706807491,
#    'eigen': 0.022100467668230914}),
#  (' chapter-4 bhargava',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.003242329207392878,
#    'eigen': 0.022326477709036754}),
#  (' chapter-14 pharrington',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-7 bragilevsky',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0034700860705772617,
#    'eigen': 1.5131699152200079e-05}),
#  (' chapter-2 bragilevsky',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0016846311898577426,
#    'eigen': 0.0007196054318566793}),
#  (' chapter-1 bragilevsky',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.003821836617101568,
#    'eigen': 0.0004037040867284327}),
#  (' about-this-book johnsson',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0025167387739821745,
#    'eigen': 0.020282261899750464}),
#  (' chapter-1 vehent',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.00048772987706967004,
#    'eigen': 0.005416657632532354}),
#  (' chapter-2 vehent',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 0.0014465861993288266}),
#  (' a-docker-fundamental siriwardena',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-2 psaltis',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-3 foulds2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 5.091126065445408e-07,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-9 psaltis',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 6.376366434125559e-25}),
#  (' chapter-2 stoneman',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-8 pollard',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0004821296383976801,
#    'eigen': 6.376366434125559e-25}),
#  (' chapter-1 duncan',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-1 khan',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.006193451048346315,
# ...
#    'eigen': 0.01751101703297838}),
#  (' chapter-4 cai',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0005463955623394441,
#    'eigen': 0.030875040659115272}),
#  (' chapter-7 elgendy',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0012640223465575928,
#    'eigen': 0.04225961225857623}),
#  (' chapter-8 elgendy',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0014494481385997615,
#    'eigen': 0.02147579463868963}),
#  (' chapter-1 elgendy',
#   {'out-degree': 0.003566333808844508,
#    'betweenness': 0.007491568557521197,
#    'eigen': 0.06927427186698325}),
#  (' copyright-2019-manning-publications elgendy',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0007792755544424445,
#    'eigen': 0.026053353243033036}),
#  (' chapter-1 raaijmakers',
#   {'out-degree': 0.003566333808844508,
#    'betweenness': 0.014171796832433546,
#    'eigen': 0.07040928720193003}),
#  (' chapter-3 allaire',
#   {'out-degree': 0.0042796005706134095,
#    'betweenness': 0.01398479818441703,
#    'eigen': 0.09581349375482764}),
#  (' list-of-figures allaire',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.00038347536400180725,
#    'eigen': 0.019531897443345103}),
#  (' chapter-4 allaire',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0007299359881095368,
#    'eigen': 0.02583934671135422}),
#  (' part-2 allaire',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0013215507623909669,
#    'eigen': 0.025606088997038277}),
#  (' welcome zai',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0059646308899072,
#    'eigen': 0.018972394656881227}),
#  (' chapter-6 allaire',
#   {'out-degree': 0.0042796005706134095,
#    'betweenness': 0.00655525069301276,
#    'eigen': 0.07354890007642946}),
#  (' brief-contents elgendy',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.000486711651856581,
#    'eigen': 0.019655750688505783}),
#  (' table-of-contents elgendy',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0004811114131845911,
#    'eigen': 0.005253167136518554}),
#  (' chapter-5 allaire',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.001185143582941644,
#    'eigen': 0.05130985744461589}),
#  (' chapter-2 juric2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  (' chapter-7 hunter',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0004882389896762146,
#    'eigen': 0.00890962144113297}),
#  (' chapter-1 tanweihao',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 0.0023794512099976008}),
#  (' chapter-2 raaijmakers',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0009807937214394607,
#    'eigen': 0.019655750688505783}),
#  (' welcome hagiwara',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0009751934827674705,
#    'eigen': 0.005253167136518554}),
#  (' about-this-book lane',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.004730820678247218,
#    'eigen': 0.029561408614570066}),
#  (' chapter-3 harenslak',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 0.0136850037403479}),
#  (' chapter-20 kurt',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  (' chapter-6 bragilevsky',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0009652775020084493,
#    'eigen': 3.806785930821229e-26}),
#  (' chapter-9 bragilevsky',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 0.029446757910377215}),
#  (' chapter-3 ponelat',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.00319685262380883,
#    'eigen': 0.029446757910377215}),
#  (' welcome graingert',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  (' chapter-1 graingert',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.00048212963839768013,
#    'eigen': 3.806785930821228e-26}),
#  (' chapter-2 graingert',
#   {'out-degree': 0.005706134094151213,
#    'betweenness': 0.021397133726477287,
#    'eigen': 0.11486576821135466}),
#  (' chapter-3 teofili',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.005894033673172101,
#    'eigen': 0.043586160439284066}),
#  (' chapter-1 teofili',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0004667757058040746,
#    'eigen': 0.011640888718383395}),
#  (' chapter-3 jain',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0005873071003146718,
#    'eigen': 0.031989137344192356}),
#  (' chapter-8 buckett',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 0.014527654000064569}),
#  (' chapter-8 rfeldman',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  (' chapter-1 rfeldman',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 2.053744660314787e-06}),
#  (' about-this-book siddaway2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0038775713156454037,
#    'eigen': 0.0005069486468016418}),
#  (' chapter-2 siddaway2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.003871971076973414,
#    'eigen': 0.00018474925964862145}),
#  (' chapter-21 jones3',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.003866370838301424,
#    'eigen': 4.934590876003268e-05}),
#  (' chapter-2 lock',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-3 lock',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.002444176893647977,
#    'eigen': 0.0009913758008355527}),
#  (' chapter-12 lock',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.002438576654975987,
#    'eigen': 0.00036121833026619195}),
#  (' chapter-5 lock',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.002432976416303997,
#    'eigen': 9.64652167903801e-05}),
#  (' chapter-2 meeks2',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.004067007795213055,
#    'eigen': 0.02404958947805985}),
#  (' chapter-3 meeks2',
#   {'out-degree': 0.0028530670470756064,
#    'betweenness': 0.007778174750983912,
#    'eigen': 0.03560677313311895}),
#  (' chapter-5 fain3',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.003447883912240429,
#    'eigen': 0.005608428427175541}),
#  (' chapter-13 fain3',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.004406542950363802,
#    'eigen': 0.0020437389621108205}),
#  (' appendix-a luksa',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 6.077592349269092e-05,
#    'eigen': 4.544371579555473e-16}),
#  (' about-this-book devore',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.006311123715572245,
#    'eigen': 0.012257196945419262}),
#  (' about-this-book roestenburg',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0012146379180930612,
#    'eigen': 0.004242353238795316}),
#  (' chapter-2 devore',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0015923159424184273,
#    'eigen': 0.005851491139606185}),
#  (' chapter-13 maurer',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-41 jones6',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' about-this-book larsen2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 1.0182252130890815e-06,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-2 payette3',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 1.0182252130890815e-06,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-4 payette3',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 1.903392965410614e-26}),
#  (' chapter-1 maurer',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-3 maurer',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 1.5273378196336224e-06,
#    'eigen': 6.376366434125559e-25}),
#  (' chapter-4 maurer',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 2.036450426178163e-06,
#    'eigen': 1.0535280063547752e-23}),
#  (' chapter-5 maurer',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 1.5273378196336224e-06,
#    'eigen': 1.1446053597496731e-22}),
#  (' chapter-6 maurer',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 9.198812692884685e-22}),
#  (' chapter-1 lock',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0029044874203366052,
#    'eigen': 0.0027208460861376867}),
#  (' chapter-6 terrell',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-9 marguerie',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 2.4182848810865687e-05,
#    'eigen': 6.376366434125559e-25}),
#  (' chapter-10 marguerie',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0005058033746020013,
#    'eigen': 6.1860271375844965e-25}),
#  (' chapter-4 miell2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0009864056751800478,
#    'eigen': 9.935711279443407e-24}),
#  (' chapter-4 normand',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0011397551830384096,
#    'eigen': 0.016618595787256676}),
#  ('  preukschat',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0010682251570917822,
#    'eigen': 0.0062597276743851385}),
#  (' part-2 windmill',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 0.005796402652679598}),
#  (' chapter-9 stevens2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  (' chapter-10 stevens2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-1 iannone',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0032204882682589715,
#    'eigen': 0.013591010773370785}),
#  (' part-1 chollet',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 5.159156970479536e-46}),
#  (' chapter-2 carroll',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-3 ceder2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 6.10935127853449e-06,
#    'eigen': 6.376366434125558e-25}),
#  (' part-2 ceder2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 1.1200477343979896e-05,
#    'eigen': 6.186027137584496e-25}),
#  (' chapter-5 ceder2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 1.527337819633622e-05,
#    'eigen': 9.935711279443401e-24}),
#  (' chapter-6 ceder2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 1.8328053835603467e-05,
#    'eigen': 1.0516246133893643e-22}),
#  (' chapter-4 ceder2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 2.036450426178163e-05,
#    'eigen': 8.252540880130799e-22}),
#  (' chapter-7 ceder2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 2.1382729474870713e-05,
#    'eigen': 5.122154190462713e-21}),
#  (' chapter-9 ceder2',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 2.9019418573038824e-05,
#    'eigen': 1.1252835962419133e-15}),
#  (' chapter-8 ceder2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 1.934627904869255e-05,
#    'eigen': 5.981467357046697e-16}),
#  (' chapter-10 ceder2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 1.6291603409425305e-05,
#    'eigen': 6.787239131668829e-16}),
#  (' chapter-18 ceder2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 1.323692777015806e-05,
#    'eigen': 7.701673296960381e-16}),
#  (' chapter-12 ceder2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 1.0182252130890815e-05,
#    'eigen': 8.739386770979776e-16}),
#  (' chapter-13 ceder2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 7.127576491623571e-06,
#    'eigen': 9.916822389855018e-16}),
#  (' chapter-15 ceder2',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 5.981467357046697e-16}),
#  (' chapter-21 kurt',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-1 kopec2',
#   {'out-degree': 0.003566333808844508,
#    'betweenness': 0.01518829881789659,
#    'eigen': 0.06789958186859735}),
#  (' about-this-book kopec2',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0024209572976075784,
#    'eigen': 0.007864148785708356}),
#  (' chapter-9 garreau',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0014251326034813684,
#    'eigen': 0.0009915386684935276}),
#  (' chapter-3 mcnamara',
#   {'out-degree': 0.0021398002853067048,
#    'betweenness': 0.0028705032934613194,
#    'eigen': 0.007465819093111175}),
#  (' chapter-3 geers',
#   {'out-degree': 0.003566333808844508,
#    'betweenness': 0.010351188102223418,
#    'eigen': 0.01949488171978074}),
#  (' chapter-4 mcnamara',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0009703686280738947,
#    'eigen': 0.0027207698725278816}),
#  (' chapter-7 borgatti',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 0.0002648362108137889}),
#  (' part-3 khorikov',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0010758822157802504,
#    'eigen': 0.014661743645254544}),
#  (' chapter-8 khorikov',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0010702819771082608,
#    'eigen': 0.003915671162571694}),
#  (' about-this-book prasanna',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0010646817384362707,
#    'eigen': 0.0010457430815979235}),
#  (' about-this-book walls5',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 0.00304621036606909}),
#  (' about-this-book fairbairn',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.00048772987706967004,
#    'eigen': 0.015556297226136355}),
#  (' about-this-book cahill',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 0.004154556038142256}),
#  (' chapter-2 langr',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-4 richer2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 0.010179912834042942}),
#  (' about-this-book garreau',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0010350598699454875,
#    'eigen': 0.005796402652679598}),
#  (' chapter-2 fain',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 0.00014978920169509574}),
#  (' about-this-book pharrington',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.001099005774674241,
#    'eigen': 0.001110128612844628}),
#  (' chapter-9 petricek',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.004354440123775457,
#    'eigen': 0.013777234048723752}),
#  (' about-this-book smart',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.004830969523501147,
#    'eigen': 0.003679475282520169}),
#  (' chapter-8 umali',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-9 umali',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.00048263875100422465,
#    'eigen': 1.903392965410614e-26}),
#  (' chapter-14 umali',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0009642592767953603,
#    'eigen': 6.376366434125559e-25}),
#  (' chapter-6 grant2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.00625750304703895,
#    'eigen': 4.791338838421437e-05}),
#  (' chapter-9 grant2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.00625190280836696,
#    'eigen': 1.7459717526778597e-05}),
#  (' chapter-3 grant2',
#   {'out-degree': 0.0014265335235378032,
#    'betweenness': 0.0024116664172014897,
#    'eigen': 0.0004923127551635804}),
#  (' part-2 grant2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0024060661785294995,
#    'eigen': 0.00013148548427235662}),
#  (' chapter-5 sbarski2',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 0.0051108512172293044}),
#  (' chapter-4 ponge',
#   {'out-degree': 0.0, 'betweenness': 0.0, 'eigen': 1.6259327276329826e-17}),
#  (' about-this-book chang',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0014647169690286438,
#    'eigen': 0.005796402652679598}),
#  (' chapter-4 teofili',
#   {'out-degree': 0.0007132667617689016,
#    'betweenness': 0.0,
#    'eigen': 1.903392965410614e-26}),
#  ...]

# %%
# create a dictionary from the list
data = {}

data["chapter"] = [x[0] for x in data_list]

data["out-degree"] = [x[1]["out-degree"] for x in data_list]
data["eigen"] = [x[1]["eigen"] for x in data_list]
data["betweenness"] = [x[1]["betweenness"] for x in data_list]

# %%
# create a dataframe from dictionary with columns/series chapter, out-degree, eigen, betweenness
df2 = pd.DataFrame(data)

# %%
# create a list with nodes that are connected to the defined node
row = [n for n in G[' chapter-1 munro']]
row
# Out:
# [' about-this-book lauret',
#  ' chapter-3 fain4',
#  ' chapter-11 lauret',
#  ' chapter-1 ghosh',
#  ' about-this-book hocking2',
#  ' chapter-1 hudgeon',
#  ' introduction fain4',
#  ' chapter-1 munro',
#  ' welcome lemaire',
#  ' chapter-1 seemann2']

# %%
# create a dataframe with a single colum from list so it can be used for an inner join
df3 = pd.DataFrame(row)

# %%
# make the list of connected nodes the index of the dataframe
df3 = df3.set_index(0)
df3
# Out:
# Empty DataFrame
# Columns: []
# Index: [ about-this-book lauret,  chapter-3 fain4,  chapter-11 lauret,  chapter-1 ghosh,  about-this-book hocking2,  chapter-1 hudgeon,  introduction fain4,  chapter-1 munro,  welcome lemaire,  chapter-1 seemann2]

# %%
# make the chapter also the index of the df2 and inner join by chapter
# only nodes that are connected to the defined node will be part of the joined dataframe df4
df4 = df3.join(df2.set_index("chapter"))

# %%
# sort by a selected (here: betweenness) centrality in order to be able to make a recommendation
df4 = df4.sort_values(by=["betweenness"], ascending=False)

# %%
# When you read the chapter-1 of the book munro the recommended next chapter is "about-this-book" from the book "lauret"
df4
# Out:
#                            out-degree     eigen  betweenness
# 0
#  chapter-1 munro             0.007133  0.205791     0.037793
#  about-this-book lauret      0.005706  0.114395     0.029768
#  chapter-1 seemann2          0.002853  0.125462     0.016467
#  chapter-11 lauret           0.003566  0.203417     0.010509
#  welcome lemaire             0.001427  0.054961     0.004219
#  about-this-book hocking2    0.000713  0.061837     0.002087
#  chapter-1 hudgeon           0.002140  0.109563     0.001448
#  chapter-1 ghosh             0.000713  0.054961     0.001247
#  chapter-3 fain4             0.000713  0.054961     0.000914
#  introduction fain4          0.000713  0.054961     0.000000
